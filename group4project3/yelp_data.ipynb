# %%
import pandas as pd

# %%
yelp = "../Project-3/yelp_business.csv"
yelp_data = pd.read_csv(yelp)
yelp_data.head()
# Out:
#               business_id                        name neighborhood  \
# 0  FYWN1wneV18bWNgQjJ2GNg          "Dental by Design"          NaN
# 1  He-G7vWjzVUysIKrfNbPUQ       "Stephen Szabo Salon"          NaN
# 2  KQPW8lFf1y5BT2MxiSZ3QA     "Western Motor Vehicle"          NaN
# 3  8DShNS-LuFqpEWIp0HxijA          "Sports Authority"          NaN
# 4  PfOCPjBrlQAnz__NXj9h_w  "Brick House Tavern + Tap"          NaN
#
#                             address            city state postal_code  \
# 0        "4855 E Warner Rd, Ste B9"       Ahwatukee    AZ       85044
# 1              "3101 Washington Rd"        McMurray    PA       15317
# 2          "6025 N 27th Ave, Ste 1"         Phoenix    AZ       85017
# 3  "5000 Arizona Mills Cr, Ste 435"           Tempe    AZ       85282
# 4                    "581 Howe Ave"  Cuyahoga Falls    OH       44221
#
#     latitude   longitude  stars  review_count  is_open  \
# 0  33.330690 -111.978599    4.0            22        1
# ...

# %%
organized_data = yelp_data.loc[:,["name", "address", "city", "state", "postal_code", "latitude", "longitude", "stars", "categories"]]
organized_data.head()
# Out:
#                          name                           address  \
# 0          "Dental by Design"        "4855 E Warner Rd, Ste B9"
# 1       "Stephen Szabo Salon"              "3101 Washington Rd"
# 2     "Western Motor Vehicle"          "6025 N 27th Ave, Ste 1"
# 3          "Sports Authority"  "5000 Arizona Mills Cr, Ste 435"
# 4  "Brick House Tavern + Tap"                    "581 Howe Ave"
#
#              city state postal_code   latitude   longitude  stars  \
# 0       Ahwatukee    AZ       85044  33.330690 -111.978599    4.0
# 1        McMurray    PA       15317  40.291685  -80.104900    3.0
# 2         Phoenix    AZ       85017  33.524903 -112.115310    1.5
# 3           Tempe    AZ       85282  33.383147 -111.964725    3.0
# 4  Cuyahoga Falls    OH       44221  41.119535  -81.475690    3.5
#
#                                           categories
# 0  Dentists;General Dentistry;Health & Medical;Or...
# 1  Hair Stylists;Hair Salons;Men's Hair Salons;Bl...
# ...

# %%
clt_yelp = organized_data.loc[organized_data["city"] == "Charlotte"]
clt_yelp
# Out:
#                                                      name  \
# 14                           "Showmars Government Center"
# 56                                     "My Fitness World"
# 77                               "Fairfield Inn & Suites"
# 84                                  "Scott's Karat Patch"
# 97                             "La Isla Cuban Restaurant"
# 102                                            "Pep Boys"
# 103                      "Finga Lickin' Caribbean Eatery"
# 126                                        "China Buffet"
# 128                                         "Duck Donuts"
# 155                                           "Felicitea"
# 163                             "Dockside Seafood Market"
# 235                        "University Dental Associates"
# 423                                 "Cigarettes and More"
# 462                                         "Dollar Tree"
# 485                                   "Now It's A Party!"
# ...

# %%
clt_yelp.to_csv("../Project-3/new_yelp.csv", index=False, header=True)
